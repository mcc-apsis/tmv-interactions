# %%
import os, sys, time, resource, re, gc, shutil, math
from nltk import ngrams
from multiprocess import Pool
from functools import partial
from mongoengine import *
from urllib.parse import urlparse, parse_qsl
import numpy as np
import pandas as pd
connect('mongoengine_documents')
import matplotlib.pyplot as plt

from gensim.models import Word2Vec, Doc2Vec
from gensim.models import Phrases
import gensim

import django

sys.path.append('/home/galm/software/django/tmv/BasicBrowser/')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "BasicBrowser.settings")
django.setup()

from scoping.models import *

import pymongo
from pymongo import MongoClient
from monary import Monary
mon = Monary()
#client = MongoClient()
#db = client.documents
#scopus_docs = db.scopus_docs

from mongo_classes import *

# %%
scopus_doc.objects.filter(doc2vec_checked=True).count()
# Out:
# 3000

# %%
similarity.objects.filter(doc2vec_rank__gt=0).count()
# Out:
# 1078924

# %%
sims = similarity.objects.filter(doc2vec_sim__gt=0)
sims.count()
# Out:
# 1080644

# %%
similarity.objects.filter(doc2vec_sim__gt=0,jaccard=0).count()
# Out:
# 917376

# %%
columns = ['do_match', 'doc2vec_sim','jaccard', 'wc_diff','wc','t_match','doc2vec_rank']
numpy_arrays = mon.query('mongoengine_documents', 
                        'similarity', 
                        { "doc2vec_sim": {"$exists": True},"scopus_do":True, "wos_do": True},
                        columns, 
                        ['bool', 'float32','float32', 'int8','int8','bool','int8'])
df = np.matrix(numpy_arrays).transpose() 
df = pd.DataFrame(df, columns=columns)
print(df.shape)
df.head()
# Out:
# (537057, 7)
#    do_match  doc2vec_sim   jaccard  wc_diff    wc  t_match  doc2vec_rank
# 0       1.0     0.853627  0.583333      1.0  10.0      0.0           1.0
# 1       1.0     0.774050  0.333333      1.0  15.0      0.0           1.0
# 2       0.0     0.697606  0.727273      1.0  10.0      0.0           1.0
# 3       1.0     0.404488  1.000000      0.0   7.0      0.0        -109.0
# 4       0.0     0.558295  0.750000      2.0   8.0      0.0          18.0

# %%
pdf = df#.sample(frac=0.5, replace=True)

fig_size = [None,None]
fig_size[0] = 12
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size

def rand_jitter(arr):
    stdev = .01*(max(arr)-min(arr))
    return arr + np.random.randn(len(arr)) * stdev

def jitter(x, y, s=20, marker='o', cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, hold=None, **kwargs):
    return plt.scatter(rand_jitter(x), rand_jitter(y), s=s, marker=marker, cmap=cmap, norm=norm, vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths, verts=verts, hold=hold, **kwargs)

for name, group in pdf.groupby('do_match'):
    jitter(group['jaccard'], group['doc2vec_sim'], s=4, cmap='Set1')

plt.legend()
plt.xlabel('jaccard')
plt.ylabel('doc2vec_sim')

plt.show()

# %%
pdf = df#.sample(frac=0.5, replace=True)

fig_size = [None,None]
fig_size[0] = 12
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size

for name, group in pdf.groupby('do_match'):
    jitter(group['jaccard'], group['doc2vec_rank'], s=4, cmap='Set1')

plt.legend()
plt.xlabel('jaccard')
plt.ylabel('doc2vec_sim')

plt.show()

# %%
columns = ['do_match', 'doc2vec_sim','jaccard', 'wc_diff','wc','t_match','doc2vec_rank']

numpy_arrays = mon.query('mongoengine_documents', 
                        'similarity', 
                        { "doc2vec_sim": {"$exists": True}, "do_match": True},
                        columns, 
                        ['bool', 'float32','float32', 'int8','int8','bool','int8'])
matches = np.matrix(numpy_arrays).transpose() 
match_df = pd.DataFrame(matches, columns=columns)

print(similarity.objects.filter(doc2vec_sim__gt=0,do_match=True).count())

match_df.head(13)

#match_df = pd.DataFrame.from_dict(list(matches.values()))
# Out:
# 764
#     do_match  doc2vec_sim   jaccard  wc_diff    wc  t_match  doc2vec_rank
# 0        1.0     0.853883  0.583333      1.0  10.0      0.0           1.0
# 1        1.0     0.773843  0.333333      1.0  15.0      0.0           1.0
# 2        1.0     0.403739  1.000000      0.0   7.0      0.0         118.0
# 3        1.0     0.785536  1.000000      0.0   8.0      0.0           1.0
# 4        1.0     0.357723  0.176471     20.0  21.0      0.0         -44.0
# 5        1.0     0.698044  0.583333      1.0  10.0      0.0           1.0
# 6        1.0     0.803269  0.375000      0.0  12.0      0.0           3.0
# 7        1.0     0.862255  1.000000      0.0   9.0      0.0           1.0
# 8        1.0     0.791839  0.583333      1.0  10.0      0.0           1.0
# 9        1.0     0.549643  1.000000      0.0   6.0      0.0          51.0
# 10       1.0     0.710493  0.545455      1.0   9.0      0.0           1.0
# 11       1.0     0.461626  0.307692      1.0   9.0      0.0         -43.0
# 12       1.0     0.455639  0.705882      1.0  15.0      0.0        -124.0

# %%
def shingle(text,k):

    text = text.lower()
    shingleLength = k
    tokens = text.split()

    shingles = [tokens[i:i+shingleLength] for i in range(len(tokens) - shingleLength + 1) if len(tokens[i]) < 4]
    shingles = ngrams(tokens,k)
    s_set = set()
    for s in shingles:
        s_set.add(s)

    return s_set

def jaccard(s1,s2):
    try:
        return len(s1.intersection(s2)) / len(s1.union(s2))
    except:
        return 0


hard_sims = similarity.objects.filter(doc2vec_sim__gt=0,jaccard__lt=0.2,do_match=True).order_by('doc2vec_sim')
for s in hard_sims[:5]:
    print('')
    d1 = scopus_doc.objects.get(scopus_id=s.scopus_id)
    print(d1.TI)
    print(d1.DO)
    d2 = Doc.objects.get(UT__UT=s.wos_ut)
    print(d2.title)
    print(d2.wosarticle.di)
    print(f"doc2vec sim: {s.doc2vec_sim}")
    print(f"jaccard (saved): {s.jaccard}")
    print(shingle(d1.TI,2))
    print(d2.shingle())
    print(jaccard(shingle(d1.TI,2),d2.shingle()))
# Out:
# A commentary on: Tropical forests and the greenhouse effect: A management response - Why should developing tropical countries plant trees? (A look to biomass fuels to approach zero net CO2 emissions)
# 10.1007/BF00142230
# TROPICAL FORESTS AND THE GREENHOUSE-EFFECT - A MANAGEMENT RESPONSE - COMMENT
# 10.1007/BF00142230
# doc2vec sim: 0.3577233552932739
# jaccard (saved): 0.17647058823529413
# {('-', 'why'), ('to', 'biomass'), ('commentary', 'on:'), ('a', 'commentary'), ('co2', 'emissions)'), ('fuels', 'to'), ('should', 'developing'), ('response', '-'), ('tropical', 'countries'), ('countries', 'plant'), ('greenhouse', 'effect:'), ('why', 'should'), ('tropical', 'forests'), ('net', 'co2'), ('effect:', 'a'), ('a', 'management'), ('look', 'to'), ('biomass', 'fuels'), ('forests', 'and'), ('trees?', '(a'), ('the', 'greenhouse'), ('zero', 'net'), ('developing', 'tropical'), ('plant', 'trees?'), ('and', 'the'), ('to', 'approach'), ('on:', 'tropical'), ('management', 'response'), ('approach', 'zero'), ('(a', 'look')}
# {('-', 'a'), ('a', 'management'), ('and', 'the'), ('-', 'comment'), ('forests', 'and'), ('response', '-'), ('tropical', 'forests'), ('management', 'response'), ('greenhouse-effect', '-'), ('the', 'greenhouse-effect')}
# 0.17647058823529413
#
# Satellite remote sensing of surface energy and mass balance: Results from FIFE
# 10.1016/0034-4257(91)90011-T
# SATELLITE REMOTE-SENSING OF SURFACE-ENERGY AND MASS BALANCE - RESULTS FROM FIFE
# 10.1016/0034-4257(91)90011-T
# doc2vec sim: 0.4467991590499878
# jaccard (saved): 0.16666666666666666
# {('from', 'fife'), ('sensing', 'of'), ('satellite', 'remote'), ('energy', 'and'), ('mass', 'balance:'), ('results', 'from'), ('surface', 'energy'), ('remote', 'sensing'), ('balance:', 'results'), ('and', 'mass'), ('of', 'surface')}
# {('mass', 'balance'), ('of', 'surface-energy'), ('-', 'results'), ('from', 'fife'), ('results', 'from'), ('surface-energy', 'and'), ('satellite', 'remote-sensing'), ('balance', '-'), ('and', 'mass'), ('remote-sensing', 'of')}
# 0.16666666666666666
#
# Global energy balance and regional hydrology: A Burgundian case study
# 10.1002/esp.3290160703
# GLOBAL ENERGY-BALANCE AND REGIONAL HYDROLOGY - A BURGUNDIAN CASE-STUDY
# 10.1002/esp.3290160703
# doc2vec sim: 0.46197250485420227
# jaccard (saved): 0.13333333333333333
# {('energy', 'balance'), ('regional', 'hydrology:'), ('case', 'study'), ('hydrology:', 'a'), ('and', 'regional'), ('a', 'burgundian'), ('burgundian', 'case'), ('balance', 'and'), ('global', 'energy')}
# {('-', 'a'), ('burgundian', 'case-study'), ('and', 'regional'), ('hydrology', '-'), ('a', 'burgundian'), ('regional', 'hydrology'), ('energy-balance', 'and'), ('global', 'energy-balance')}
# 0.13333333333333333
#
# A commentary on: Palaeoecological background: Neotropics
# 10.1007/BF00142212
# PALEOECOLOGICAL BACKGROUND - NEOTROPICS - COMMENT
# 10.1007/BF00142212
# doc2vec sim: 0.5070796608924866
# jaccard (saved): 0.0
# {('background:', 'neotropics'), ('palaeoecological', 'background:'), ('on:', 'palaeoecological'), ('commentary', 'on:'), ('a', 'commentary')}
# {('background', '-'), ('paleoecological', 'background'), ('-', 'comment'), ('-', 'neotropics'), ('neotropics', '-')}
# 0.0
#
# Global warming, population growth, and natural resources for food production
# 10.1080/08941929109380766
# GLOBAL WARMING, POPULATION-GROWTH, AND NATURAL-RESOURCES FOR FOOD-PRODUCTION
# 10.1080/08941929109380766
# doc2vec sim: 0.509488582611084
# jaccard (saved): 0.07142857142857142
# {('population', 'growth,'), ('growth,', 'and'), ('global', 'warming,'), ('natural', 'resources'), ('food', 'production'), ('resources', 'for'), ('and', 'natural'), ('for', 'food'), ('warming,', 'population')}
# {('and', 'natural-resources'), ('population-growth,', 'and'), ('for', 'food-production'), ('global', 'warming,'), ('warming,', 'population-growth,'), ('natural-resources', 'for')}
# 0.07142857142857142
